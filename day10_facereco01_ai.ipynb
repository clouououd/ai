# %% [markdown]
# <a href="https://colab.research.google.com/github/clouououd/ai/blob/main/day10_facereco01_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Client ID : YuqAa_xzo9GHDHjPiZCN
# PW :        lMJDnwMf8R

import os
import sys
import requests

client_id = "YuqAa_xzo9GHDHjPiZCN"
client_secret = "lMJDnwMf8R"

url = "https://openapi.naver.com/v1/vision/face" # 얼굴감지
# url = "https://openapi.naver.com/v1/vision/celebrity" # 유명인 얼굴인식

files = {'image': open('image3.jpg', 'rb')}
headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret }
response = requests.post(url,  files=files, headers=headers)

rescode = response.status_code
if(rescode==200):
    print (response.text)
else:
    print("Error Code:" + rescode)
# Out:
# {"info":{"size":{"width":1200,"height":847},"faceCount":7},"faces":[{"roi":{"x":341,"y":279,"width":60,"height":60},"landmark":{"leftEye":{"x":357,"y":292},"rightEye":{"x":384,"y":295},"nose":{"x":370,"y":308},"leftMouth":{"x":358,"y":324},"rightMouth":{"x":381,"y":325}},"gender":{"value":"male","confidence":0.999998},"age":{"value":"31~35","confidence":0.577669},"emotion":{"value":"neutral","confidence":0.999998},"pose":{"value":"frontal_face","confidence":0.999404}},{"roi":{"x":836,"y":266,"width":59,"height":59},"landmark":{"leftEye":{"x":856,"y":284},"rightEye":{"x":882,"y":282},"nose":{"x":870,"y":298},"leftMouth":{"x":859,"y":313},"rightMouth":{"x":882,"y":311}},"gender":{"value":"male","confidence":0.999996},"age":{"value":"38~42","confidence":0.331422},"emotion":{"value":"smile","confidence":0.747392},"pose":{"value":"frontal_face","confidence":0.995238}},{"roi":{"x":518,"y":251,"width":51,"height":51},"landmark":{"leftEye":{"x":532,"y":263},"rightEye":{"x":554,"y":264},"nose
# ...

# %%
# import os ............운영체제 접근
# import sys ...........시스템 접근
# import requests ......웹 접근 _ 네이버에 요청

# client_id = "YOUR_CLIENT_ID"
# client_secret = "YOUR_CLIENT_SECRET"

# # url = "https://openapi.naver.com/v1/vision/face" // 얼굴감지
# url = "https://openapi.naver.com/v1/vision/celebrity" // 유명인 얼굴인식 ..... ......이곳에 사진을 보낼 위치

# files = {'image': open('YOUR_FILE_NAME', 'rb')}
# headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret }
# response = requests.post(url,  files=files, headers=headers) ........................url에 files를 던진다 hearers는 id,pw

# rescode = response.status_code ......................................................분석결과를 받는다
# if(rescode==200):
#     print (response.text)
# else:
#     print("Error Code:" + rescode)

# %%
import json

parsed = json.loads(response.text)

type(parsed)
# Out:
# dict

# %%
print(parsed)
# Out:
# {'info': {'size': {'width': 1200, 'height': 847}, 'faceCount': 7}, 'faces': [{'roi': {'x': 341, 'y': 279, 'width': 60, 'height': 60}, 'landmark': {'leftEye': {'x': 357, 'y': 292}, 'rightEye': {'x': 384, 'y': 295}, 'nose': {'x': 370, 'y': 308}, 'leftMouth': {'x': 358, 'y': 324}, 'rightMouth': {'x': 381, 'y': 325}}, 'gender': {'value': 'male', 'confidence': 0.999998}, 'age': {'value': '31~35', 'confidence': 0.577669}, 'emotion': {'value': 'neutral', 'confidence': 0.999998}, 'pose': {'value': 'frontal_face', 'confidence': 0.999404}}, {'roi': {'x': 836, 'y': 266, 'width': 59, 'height': 59}, 'landmark': {'leftEye': {'x': 856, 'y': 284}, 'rightEye': {'x': 882, 'y': 282}, 'nose': {'x': 870, 'y': 298}, 'leftMouth': {'x': 859, 'y': 313}, 'rightMouth': {'x': 882, 'y': 311}}, 'gender': {'value': 'male', 'confidence': 0.999996}, 'age': {'value': '38~42', 'confidence': 0.331422}, 'emotion': {'value': 'smile', 'confidence': 0.747392}, 'pose': {'value': 'frontal_face', 'confidence': 0.995238}}, {'r
# ...

# %%
print(json.dumps(parsed, indent = 4))

# %%
parsed.keys()
# Out:
# dict_keys(['info', 'faces'])

# %%
print(parsed['info'])
# Out:
# {'size': {'width': 1200, 'height': 847}, 'faceCount': 7}

# %%
# 인식된 얼굴들
print(parsed['faces'])
# Out:
# [{'roi': {'x': 341, 'y': 279, 'width': 60, 'height': 60}, 'landmark': {'leftEye': {'x': 357, 'y': 292}, 'rightEye': {'x': 384, 'y': 295}, 'nose': {'x': 370, 'y': 308}, 'leftMouth': {'x': 358, 'y': 324}, 'rightMouth': {'x': 381, 'y': 325}}, 'gender': {'value': 'male', 'confidence': 0.999998}, 'age': {'value': '31~35', 'confidence': 0.577669}, 'emotion': {'value': 'neutral', 'confidence': 0.999998}, 'pose': {'value': 'frontal_face', 'confidence': 0.999404}}, {'roi': {'x': 836, 'y': 266, 'width': 59, 'height': 59}, 'landmark': {'leftEye': {'x': 856, 'y': 284}, 'rightEye': {'x': 882, 'y': 282}, 'nose': {'x': 870, 'y': 298}, 'leftMouth': {'x': 859, 'y': 313}, 'rightMouth': {'x': 882, 'y': 311}}, 'gender': {'value': 'male', 'confidence': 0.999996}, 'age': {'value': '38~42', 'confidence': 0.331422}, 'emotion': {'value': 'smile', 'confidence': 0.747392}, 'pose': {'value': 'frontal_face', 'confidence': 0.995238}}, {'roi': {'x': 518, 'y': 251, 'width': 51, 'height': 51}, 'landmark': {'leftEye'
# ...

# %%
# 4번째 얼굴 정보
parsed['faces'][4]
# Out:
# {'age': {'confidence': 0.638639, 'value': '50~54'},
#  'emotion': {'confidence': 0.925973, 'value': 'neutral'},
#  'gender': {'confidence': 0.999803, 'value': 'male'},
#  'landmark': {'leftEye': {'x': 716, 'y': 191},
#   'leftMouth': {'x': 715, 'y': 219},
#   'nose': {'x': 729, 'y': 206},
#   'rightEye': {'x': 741, 'y': 192},
#   'rightMouth': {'x': 739, 'y': 219}},
#  'pose': {'confidence': 0.999538, 'value': 'frontal_face'},
#  'roi': {'height': 56, 'width': 56, 'x': 698, 'y': 179}}

# %%
import matplotlib.pyplot as plt # 사진 관련 기본 모듈
import matplotlib.image as mpimg # 사진 읽어오는 모듈
import matplotlib.patches as patches # 사진 수정 관련 모듈

img = mpimg.imread('image3.jpg') # 사진 읽어오기
fig, ax = plt.subplots(figsize=(10,10)) # 사진을 표시할 액자와 사진 설정 / fig : 사진, ax : 액자
ax.imshow(img) # 액자에 사진 삽입

print(parsed['faces'][1]['roi'].values()) # 1번째 얼굴의 위치정보(roi) 출력
x, y, w, h = parsed['faces'][0]['roi'].values() # 얼굴의 위치정보 변수에 할당

re_face = patches.Rectangle((x, y),w ,h, facecolor='none', edgecolor='r') # 그 위치에 직사각형을 생성(시작점(x,y), 너비, 높이, 면색=없음, 테두리색=빨강)
ax.add_patch(re_face) # 사진에 정보를 올려 수정
# Out:
# dict_values([836, 266, 59, 59])

# %%
import matplotlib.pyplot as plt # 사진 관련 기본 모듈
import matplotlib.image as mpimg # 사진 읽어오는 모듈
import matplotlib.patches as patches # 사진 수정 관련 모듈

img = mpimg.imread('image3.jpg') # 사진 읽어오기
fig, ax = plt.subplots(figsize=(10,10)) # 사진을 표시할 액자와 사진 설정 / fig : 사진, ax : 액자 / figsize -> size 크기 설정
ax.imshow(img) # 액자에 사진 삽입


for i in range(parsed['info']['faceCount']) :
  x, y, w, h = parsed['faces'][i]['roi'].values() # 얼굴의 위치정보 변수에 할당
  
  re_face = patches.Rectangle((x, y),w ,h, facecolor='none', edgecolor='r') # 그 위치에 직사각형을 생성(시작점(x,y), 너비, 높이, 면색=없음, 테두리색=빨강)
  ax.add_patch(re_face) # 사진에 정보를 올려 수정

# %%
# 각 사람의 얼굴 아래(오른쪽) 성별, 나이 표시
import matplotlib.pyplot as plt # 사진 관련 기본 모듈
import matplotlib.image as mpimg # 사진 읽어오는 모듈
import matplotlib.patches as patches # 사진 수정 관련 모듈

img = mpimg.imread('image3.jpg') # 사진 읽어오기
fig, ax = plt.subplots(figsize=(10,10)) # 사진을 표시할 액자와 사진 설정 / fig : 사진, ax : 액자
ax.imshow(img) # 액자에 사진 삽입

x, y, w, h = parsed['faces'][0]['roi'].values() # 얼굴의 위치정보 변수에 할당
age, age_conf = parsed['faces'][0]['age'].values()
gender, gender_conf = parsed['faces'][0]['gender'].values()

anno = gender + ',' + age
plt.text(x,y, anno, color='blue')

re_face = patches.Rectangle((x, y),w ,h, facecolor='none', edgecolor='r') # 그 위치에 직사각형을 생성(시작점(x,y), 너비, 높이, 면색=없음, 테두리색=빨강)
ax.add_patch(re_face) # 사진에 정보를 올려 수정

# %%
import matplotlib.pyplot as plt # 사진 관련 기본 모듈
import matplotlib.image as mpimg # 사진 읽어오는 모듈
import matplotlib.patches as patches # 사진 수정 관련 모듈

img = mpimg.imread('image3.jpg') # 사진 읽어오기
fig, ax = plt.subplots(figsize=(10,10)) # 사진을 표시할 액자와 사진 설정 / fig : 사진, ax : 액자 / figsize -> size 크기 설정
ax.imshow(img) # 액자에 사진 삽입


for i in range(parsed['info']['faceCount']) :
  x, y, w, h = parsed['faces'][i]['roi'].values() # 얼굴의 위치정보 변수에 할당
  
  re_face = patches.Rectangle((x, y),w ,h, facecolor='none', edgecolor='r') # 그 위치에 직사각형을 생성(시작점(x,y), 너비, 높이, 면색=없음, 테두리색=빨강)
  ax.add_patch(re_face) # 사진에 정보를 올려 수정

  age, age_conf = parsed['faces'][i]['age'].values()
  gender, gender_conf = parsed['faces'][i]['gender'].values()

  anno = gender + ',' + age
  plt.text(x,y+h+20, anno, color='blue')
