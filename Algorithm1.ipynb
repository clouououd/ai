# %% [markdown]
# <a href="https://colab.research.google.com/github/clouououd/ai/blob/main/Algorithm1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 순차, 선택, 반복 diagram
# ![순차,선택,반복_diagram.drawio.png](data:image/png;base64,...)

# %%
# 의사 코드 pseudo code
# 1. 순차구조
# 	- 슈퍼마켓을 간다.
# 	- 라면을 산다.
# 	- 집으로 돌아온다.
# 2. 선택구조
# 	- 슈퍼마켓을 간다.
# 	- 라면이 있나?
# 		라면을 산다
# 		---------------------
# 		떡을 산다
# 	- 집으로 돌아온다.
# 3. 반복구조
# 	- 슈퍼마켓에 간다
# 	- 라면이 있나?
# 		라면을 산다
# 		---------------------
# 		떡을 산다
# 	- 거스름 돈이 500원 보다 많다
# 		붕어빵을 산다
# 	- 집으로 돌아온다.

# %%
# 삼각형의 면적을 계산하는 알고리즘
삼각형의 면적 = 밑변 * 높이 / 2  
의사코드로 작성
- 밑변과 높이를 입력
- area <- base * height / 2
- area <- 출력
플로우차트로 작성

# %% [markdown]
# ![삼각형의면적구하기_basic_diagram.jpg](data:image/jpeg;base64,...)

# %%
base = int(input('base값을 입력해주세요>>>'))
height = int(input('height값을 입력해주세요>>>'))

area = base * height / 2

print(area)
# Out:
# base값을 입력해주세요>>>3
# height값을 입력해주세요>>>5
# 7.5

# %%
# 두 데이터의 대소를 판단하는 알고리즘
(의사코드)
[변수]
A = 데이터값, B = 데이터값
[과정]
A와 B를 비교
[결과]
A가 크면 'A가 큽니다.'출력
B가 크면 'B가 큽니다.'출력
A와 B가 같으면 'A와 B는 같습니다..'출력

# %% [markdown]
# ![두데이터의비교_diagram.jpg](data:image/jpeg;base64,...)
