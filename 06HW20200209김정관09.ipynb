# %% [markdown]
# <a href="https://colab.research.google.com/github/clouououd/ai/blob/main/06HW20200209%EA%B9%80%EC%A0%95%EA%B4%8009.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
436. c
437. b
438. a
439. b
440. a
441. c
442. c
443. a
444. d
445. b
446. d
447. c
448. d
449. c
450. b
451. a
452. c
453. d
454. d
455. a

# %%
# Algorithm Homework
수도코드
1. 1~10000 나열, 문자형태로
2. 1에 8이 있는지 비교...10000까지 반복
3. 8이 있으면 count에 1을 더한다.
4. count 출력

# %% [markdown]
# ![AlgorithmHomework_06HW20200209김정관09.jpg](data:image/jpeg;base64,...)

# %%
from types import CoroutineType
# variable
count = 0

for i in range(10000) :
  for j in str(i) :
    if j == '8' :
      count += 1

print(count)
# Out:
# 4000
