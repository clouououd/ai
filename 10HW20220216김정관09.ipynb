# %% [markdown]
# <a href="https://colab.research.google.com/github/clouououd/ai/blob/main/10HW20220216%EA%B9%80%EC%A0%95%EA%B4%8009.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
516 c
517 d
518 d
519 c
520 b
521 a
522 b
523 a
524 c
525 a
526 c
527 c
528 b
529 d
530 a
531 a
532 d
533 b
534 a
535 b

# %%
# Algorithm Homework(#30)
1. 입력값 = 숫자 or 문자
2. 숫자 -> 정수인지 소수인지 구별
3. 문자 -> math erro
4. try, except를 이용 (eval 함수 참고)

# %% [markdown]
# ![Algorithm_Homework(#30).jpg](data:image/jpeg;base64,...)

# %%
data = input()

try :
  if type(eval(data)) == int :
    print('정수입니다')
  else :
    print('소수입니다')
except :
  print('문자입니다.')
